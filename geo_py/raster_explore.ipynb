# %%
import xarray as xr
import rioxarray
import numpy as np
import matplotlib.pyplot as plt
ras = "/home/treuter/repos/geo_py/data/USGS_1_n39w080_20230816.tif"

# xarray_data = xr.open_dataset(ras, engine='rasterio')
# xarray_data.crs

rxr = rioxarray.open_rasterio(ras)

# %%
classes_rxr = list(np.unique(rxr)) # get all unique values
print('hold')
rxr.rio.crs
rxr.rio.boun
# Out:
# hold
# CRS.from_epsg(4269)

# %%
# rxr.min(dim='x')
rxr.sum(dim='x') # sum of each x axis values for each y axis value
# Out:
# <xarray.DataArray (band: 1, y: 3612)> Size: 14kB
# array([[2579984.5, 2579413.5, 2578776. , ..., 2039490. , 2040161.5,
#         2040651.2]], dtype=float32)
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 29kB 39.0 39.0 39.0 39.0 ... 38.0 38.0 38.0 38.0
#     spatial_ref  int64 8B 0

# %%
rxr.mean(dim='band')
# Out:
# <xarray.DataArray (y: 3612, x: 3612)> Size: 52MB
# array([[652.8142 , 651.6472 , 650.34045, ..., 349.18506, 356.11923,
#         363.775  ],
#        [651.2928 , 649.0043 , 646.6827 , ..., 350.16934, 355.1016 ,
#         364.02917],
#        [652.26556, 649.41846, 646.61414, ..., 354.1755 , 360.339  ,
#         363.32925],
#        ...,
#        [918.99005, 922.7627 , 923.57477, ..., 447.98178, 448.49466,
#         449.01843],
#        [917.0433 , 914.3737 , 912.38684, ..., 449.51822, 449.81555,
#         449.99164],
#        [906.02094, 903.5553 , 902.8724 , ..., 451.17825, 451.29974,
#         451.04208]], dtype=float32)
# Coordinates:
#   * x            (x) float64 29kB -80.0 -80.0 -80.0 -80.0 ... -79.0 -79.0 -79.0
#   * y            (y) float64 29kB 39.0 39.0 39.0 39.0 ... 38.0 38.0 38.0 38.0
#     spatial_ref  int64 8B 0

# %%
# rxr.rio.bounds()
rxr.rio.nodata
# Out:
# np.float32(-999999.0)

# %%
rxr.plot()
plt.show()
